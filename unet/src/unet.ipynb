# %% [markdown]
# # Test UNET Module

# %%
from unet import AttentionUNet
import torch

model = AttentionUNet()
# count parameters
num_p = sum(p.numel() for p in model.parameters())
print(f'Number of parameters: {num_p}') 
# print number of parameters for each layer
for name, param in model.named_parameters():
    # print number of parameters with commans
    num = '{:,}'.format(param.numel())
    print(name, num)

model
# Out:
# Number of parameters: 31381349
# enc1.conv.0.weight 1,728
# enc1.conv.0.bias 64
# enc1.conv.2.weight 36,864
# enc1.conv.2.bias 64
# enc2.conv.0.weight 73,728
# enc2.conv.0.bias 128
# enc2.conv.2.weight 147,456
# enc2.conv.2.bias 128
# enc3.conv.0.weight 294,912
# enc3.conv.0.bias 256
# enc3.conv.2.weight 589,824
# enc3.conv.2.bias 256
# enc4.conv.0.weight 1,179,648
# enc4.conv.0.bias 512
# enc4.conv.2.weight 2,359,296
# enc4.conv.2.bias 512
# bottleneck.0.weight 4,718,592
# bottleneck.0.bias 1,024
# bottleneck.2.weight 9,437,184
# bottleneck.2.bias 1,024
# dec4.upconv.weight 2,097,152
# dec4.upconv.bias 512
# dec4.attention.W_g.weight 131,072
# dec4.attention.W_g.bias 256
# dec4.attention.W_x.weight 131,072
# dec4.attention.W_x.bias 256
# dec4.attention.psi.weight 256
# dec4.attention.psi.bias 1
# dec4.conv.0.weight 4,718,592
# dec4.conv.0.bias 512
# dec4.conv.2.weight 2,359,296
# dec4.conv.2.bias 512
# dec3.upconv.weight 524,288
# dec3.upconv.bias 256
# ...

# %%
x_dummy = torch.randn(1, 3, 128, 128)
out = model(x_dummy)
print(out.size())
# Out:
# torch.Size([1, 1, 128, 128])

# %%
from unet_tiny import TinyUNet
import torch

tinyNet = TinyUNet()
# count parameters
num_p = sum(p.numel() for p in tinyNet.parameters())
print(f'Number of parameters: {num_p}') 
# print number of parameters for each layer
for name, param in tinyNet.named_parameters():
    # print number of parameters with commans
    num = '{:,}'.format(param.numel())
    print(name, num)

tinyNet
# Out:
# Number of parameters: 1291828
# enc1.conv.0.weight 864
# enc1.conv.0.bias 32
# enc1.conv.2.weight 9,216
# enc1.conv.2.bias 32
# enc2.conv.0.weight 18,432
# enc2.conv.0.bias 64
# enc2.conv.2.weight 36,864
# enc2.conv.2.bias 64
# enc3.conv.0.weight 73,728
# enc3.conv.0.bias 128
# enc3.conv.2.weight 147,456
# enc3.conv.2.bias 128
# bottleneck.0.weight 147,456
# bottleneck.0.bias 128
# bottleneck.2.weight 147,456
# bottleneck.2.bias 128
# dec3.upconv.weight 65,536
# dec3.upconv.bias 128
# dec3.attention.W_g.weight 8,192
# dec3.attention.W_g.bias 64
# dec3.attention.W_x.weight 8,192
# dec3.attention.W_x.bias 64
# dec3.attention.psi.weight 64
# dec3.attention.psi.bias 1
# dec3.conv.0.weight 294,912
# dec3.conv.0.bias 128
# dec3.conv.2.weight 147,456
# dec3.conv.2.bias 128
# dec2.upconv.weight 32,768
# dec2.upconv.bias 64
# dec2.attention.W_g.weight 2,048
# dec2.attention.W_g.bias 32
# dec2.attention.W_x.weight 2,048
# dec2.attention.W_x.bias 32
# dec2.attention.psi.weight 32
# ...

# %%
from unet_tiny import TinyUNet
import torch

tinyNet = TinyUNet()
x_tiny = torch.randn(1, 3, 128, 128)
out = tinyNet(x_tiny)
print(out.size())
# Out:
# x (dec2): torch.Size([1, 64, 64, 64])
# x (dec1): torch.Size([1, 32, 128, 128])
# torch.Size([1, 1, 128, 128])

# %%
# get dataloader 
from dataloader import get_dataloaders

config = {}
train_loader, val_loader = get_dataloaders(config)

# %%
import matplotlib.pyplot as plt
count = 0
for i, (x, y) in enumerate(train_loader):
    print(x.size(), y.size())
    # out = tinyNet(x)
    # print(out.size())
    print(y.shape)
    z = y[0, 0, :, :]
    plt.imshow(z, cmap='gray')
    plt.show()
    print(z.unique())
    count += 1
    if count == 3:
        break
# Out:
# torch.Size([8, 3, 128, 128]) torch.Size([8, 1, 128, 128])
# torch.Size([8, 1, 128, 128])
# tensor([0, 1, 2])
# torch.Size([8, 3, 128, 128]) torch.Size([8, 1, 128, 128])
# torch.Size([8, 1, 128, 128])
# tensor([0, 1, 2])
# torch.Size([8, 3, 128, 128]) torch.Size([8, 1, 128, 128])
# torch.Size([8, 1, 128, 128])
# tensor([0, 1, 2])

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
from dataloader import get_dataloaders  # Import your function

# Load dataloader
config = {
    "batch_size": 4,  # Small batch for visualization
    "num_workers": 2
}
train_loader, val_loader = get_dataloaders(config)

# Get a single batch
batch = next(iter(train_loader))
x, y = batch  # x: images, y: labels

# Print tensor shapes
print(f"Image batch shape: {x.shape}")  # Should be (batch_size, channels, height, width)
print(f"Label batch shape: {y.shape}")  # Should match spatial dimensions

# Check data range
print(f"Label unique values: {torch.unique(y)}")  # Are they [0,1] or continuous?

# Convert tensors to numpy
x = x.numpy().transpose(0, 2, 3, 1)  # Convert (B, C, H, W) → (B, H, W, C)
y = y.numpy()

# Plot first few images and their corresponding labels
fig, axes = plt.subplots(2, config["batch_size"], figsize=(config["batch_size"] * 3, 6))

for i in range(config["batch_size"]):
    # Plot image
    axes[0, i].imshow(x[i])
    axes[0, i].set_title(f"Input Image {i}")
    axes[0, i].axis("off")

    # Plot label (segmentation mask)
    axes[1, i].imshow(y[i].squeeze(), cmap="gray")
    axes[1, i].set_title(f"Label {i}")
    axes[1, i].axis("off")

plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.94509804..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.99215686..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.92941177..1.0].
# Image batch shape: torch.Size([4, 3, 128, 128])
# Label batch shape: torch.Size([4, 1, 128, 128])
# Label unique values: tensor([0, 1, 2])

# %%
import sys
import os

# Get the absolute path to `src` directory
notebook_dir = os.getcwd()  # Get current notebook directory
src_path = os.path.abspath(os.path.join(notebook_dir, "/Users/itamarshamir/Documents/code/Vision/unet/src"))  # Adjust if needed
sys.path.append(src_path)  # Add 'src' to sys.path

sys.path.append("/Users/itamarshamir/Documents/code/Vision/unet")  # Adjust to your root path

import torch
import matplotlib.pyplot as plt
import torchvision.transforms.functional as TF
from unet_tiny import TinyUNet  # Import your model
from dataloader import get_dataloaders  # Import your dataloader function

# 🔹 Load trained model from checkpoint
checkpoint_path = "unet/checkpoints/best_model.ckpt"  # Update with correct path
checkpoint_path = "/Users/itamarshamir/Documents/code/Vision/unet/checkpoints/UNET_20epochs/UNET_epoch=epoch=19_val_loss=val_loss=0.2970.ckpt"
checkpoint_path = "/Users/itamarshamir/Documents/code/Vision/unet/checkpoints/UNET_20epochs/UNET_epoch=epoch=19_val_loss=val_loss=0.2645.ckpt"
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
config = {} # Ensure correct config
model = TinyUNet(config)  # Ensure correct num_classes
# model.load_state_dict(torch.load(checkpoint_path, map_location=device)["state_dict"])
checkpoint = torch.load(checkpoint_path, map_location=device)
model.load_state_dict(checkpoint["state_dict"], strict=False)  # 👈 Allow key mismatches
model.to(device)
model.eval()  # Set model to evaluation mode

model.final_conv.bias.data = torch.tensor([0.0, 0.0, 0.0], device='mps:0')

# 🔹 Load validation dataloader
config = {
    "batch_size": 4,  # Change batch size if needed
    "num_workers": 4
}
_, val_loader = get_dataloaders(config)  # Get validation data

# 🔹 Get a batch of validation images
data_iter = iter(val_loader)
images, masks = next(data_iter)
images, masks = images.to(device), masks.to(device)
# Out:
# /var/folders/xb/0_m2vys15615hn4xqm0k1_7m0000gn/T/ipykernel_38420/1243566638.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
data_iter = iter(val_loader)
images, masks = next(data_iter)
images, masks = images.to(device), masks.to(device)

# %%
# 🔹 Run inference
with torch.no_grad():
    preds = model(images)  # (B, C, H, W)
    print(f'preds: {preds.shape}')
    #z = preds[0, :, :, 10] 
    #print(z)
    #z = preds[0, :, :, 64].tolist()  # Inspect logits for one row
    preds = torch.argmax(preds, dim=1)  # Convert logits to class indices
    #print(f'preds: {preds}')
    print(f'preds: {preds.shape}')
    print(f'preds: {preds[2].unique()}')
    
# 🔹 Function to plot images
def plot_segmentation(images, masks, preds, num_samples=4):
    fig, axes = plt.subplots(num_samples, 3, figsize=(10, num_samples * 3))

    for i in range(num_samples):
        # ✅ Convert image: (3, H, W) → (H, W, 3)
        img = images[i].cpu().numpy().transpose(1, 2, 0)
        img = img * 0.5 + 0.5  # ✅ Denormalize (undo Normalize(mean=0.5, std=0.5))
        img = (img * 255).astype("uint8")  # Convert to 0-255

        # ✅ Fix mask shape (1, H, W) → (H, W)
        
        gt_mask = masks[i].cpu().numpy().squeeze(0)
        pred_mask = preds[i].cpu().numpy()
    
        axes[i, 0].imshow(img)
        axes[i, 0].set_title("Original Image")
        axes[i, 0].axis("off")

        axes[i, 1].imshow(gt_mask, cmap="gray")
        axes[i, 1].set_title("Ground Truth")
        axes[i, 1].axis("off")

        axes[i, 2].imshow(pred_mask, cmap="gray")
        axes[i, 2].set_title("Predicted Mask")
        axes[i, 2].axis("off")

    plt.tight_layout()
    plt.show()
    return gt_mask, pred_mask
# 🔹 Display results
gt_mask, pred_mask = plot_segmentation(images, masks, preds, num_samples=min(4, len(images)))
# Out:
# preds: torch.Size([4, 3, 128, 128])
# preds: torch.Size([4, 128, 128])
# preds: tensor([0, 1, 2], device='mps:0')

# %%
import math

# ln(3) = 1.09861228867

# %%
for r in z:
    # round to 2 decimal places
    r = [round(r0, 4) for r0 in r]
    print(r[:30])
# Out:
# [-0.0218, -0.0214, -0.0199, -0.02, -0.0199, -0.0206, -0.0201, -0.0205, -0.0195, -0.02, -0.0189, -0.0211, -0.0207, -0.021, -0.0202, -0.0209, -0.02, -0.0207, -0.0201, -0.021, -0.0202, -0.0214, -0.0204, -0.0207, -0.0201, -0.0207, -0.0201, -0.0207, -0.0201, -0.0207]
# [0.0494, 0.0515, 0.0549, 0.0545, 0.0541, 0.0547, 0.0543, 0.0548, 0.0543, 0.0537, 0.0546, 0.0534, 0.0505, 0.0533, 0.0534, 0.0542, 0.054, 0.055, 0.0546, 0.0556, 0.0547, 0.0547, 0.0543, 0.0551, 0.0543, 0.0549, 0.0543, 0.0549, 0.0545, 0.0551]
# [0.0357, 0.0355, 0.0384, 0.0382, 0.0382, 0.0378, 0.0382, 0.0378, 0.0375, 0.0379, 0.038, 0.0373, 0.037, 0.0376, 0.0377, 0.0377, 0.0376, 0.0376, 0.0382, 0.0376, 0.0378, 0.0373, 0.0376, 0.0376, 0.038, 0.0376, 0.038, 0.0377, 0.038, 0.0375]

# %%
w = model.final_conv.weight[:,:,0,0].tolist()
# print(w.shape)
print(model.final_conv.bias)
for r in w:
    # round to 2 decimal places
    r = [round(r0, 4) for r0 in r]
    print(r[:30])
# Out:
# Parameter containing:
# tensor([0., 0., 0.], device='mps:0', requires_grad=True)
# [-0.0729, 0.1518, 0.1034, 0.1077, 0.0207, -0.0163, -0.0646, 0.0717, -0.0782, 0.0451, 0.156, 0.1256, -0.134, -0.0037, 0.0832, 0.043, -0.109, -0.1069, 0.1046, -0.1522, -0.004, 0.047, 0.0355, -0.1674, 0.0783, 0.0005, 0.0307, 0.1437, 0.0267, -0.0312]
# [-0.0667, 0.1274, 0.0837, -0.0696, 0.142, 0.0057, 0.1423, 0.0597, 0.0149, 0.088, -0.0045, -0.0847, -0.0653, 0.016, -0.001, 0.1, -0.1653, 0.0577, -0.1387, 0.1193, -0.1234, -0.1248, -0.0075, -0.0372, -0.0984, -0.0134, -0.0549, -0.1556, -0.1324, 0.0304]
# [0.0651, -0.0691, -0.0965, -0.0036, 0.1153, 0.1244, 0.0103, 0.1119, -0.0069, 0.0531, -0.0566, 0.1565, -0.1747, -0.0548, -0.0825, -0.1164, 0.0687, -0.1033, -0.1734, -0.0477, -0.1017, -0.1527, -0.1364, 0.0023, 0.1488, 0.0388, -0.0524, -0.1052, -0.0118, -0.058]

# %%
plt.imshow(pred_mask)

# %%
for r in z:
    print(r[:30])
# Out:
# [0.022976312786340714, 0.023176999762654305, 0.021721189841628075, 0.021584896370768547, 0.02200937643647194, 0.02138725109398365, 0.021716395393013954, 0.02079511620104313, 0.01998373493552208, 0.020434482023119926, 0.021203860640525818, 0.02128227986395359, 0.023560097441077232, 0.022223224863409996, 0.02189897559583187, 0.02073269709944725, 0.021941661834716797, 0.021611342206597328, 0.02276151068508625, 0.022220594808459282, 0.022611310705542564, 0.02149214781820774, 0.022104481235146523, 0.02143070288002491, 0.022114191204309464, 0.02188868448138237, 0.022340798750519753, 0.02170936018228531, 0.02263818308711052, 0.021640796214342117]
# ...

# %%
import torch
import matplotlib.pyplot as plt
import torchvision.transforms.functional as TF
from unet_tiny import TinyUNet  # Import your model
from dataloader import get_dataloaders  # Import your dataloader function


device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
config = {} # Ensure correct config
model = TinyUNet(config)  # Ensure correct num_classes
model.to(device)
model.eval()  # Set model to evaluation mode

# 🔹 Load validation dataloader
config = {
    "batch_size": 4,  # Change batch size if needed
    "num_workers": 4
}
_, val_loader = get_dataloaders(config)  # Get validation data

# 🔹 Get a batch of validation images
data_iter = iter(val_loader)
images, masks = next(data_iter)
images, masks = images.to(device), masks.to(device)

# %%
images, masks = next(data_iter)
images, masks = images.to(device), masks.to(device)
plt.imshow(images[0].cpu().numpy().transpose(1, 2, 0))
plt.show()
with torch.no_grad():
    pred = model(images)  # (B, C, H, W)
    print(f'pred mean and std: {pred.mean()}, {pred.std()}')
    argmax = torch.argmax(pred, dim=1)  # Convert logits to class indices
    print(f'pred: {pred.shape}')
    print(f'argmax: {argmax.shape}')

# pred[0].shape = (3, 128, 128) for each class plot a histogram of the values
# plot the histograms together with different colors
# add a legend with the class names 0, 1, 2
for i in range(3):
    z = pred.cpu().numpy()
    z = z[:, i, :, :].flatten()
    plt.hist(z, bins=100, alpha=0.5, label=str(i))
plt.legend()
plt.show()

print(argmax.unique())
argmax = argmax.cpu().numpy()
for i in range(4):
    plt.imshow(argmax[i, :, :])
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].
# Decoder 3 output mean: 0.3945537209510803, std: 0.5956019163131714
# Decoder 2 output mean: 0.38769692182540894, std: 0.5705376267433167
# Decoder 1 output mean: 0.3790018558502197, std: 0.630852997303009
# pred mean and std: -0.5685994625091553, 1.4497239589691162
# pred: torch.Size([4, 3, 128, 128])
# argmax: torch.Size([4, 128, 128])
# tensor([0, 1, 2], device='mps:0')

# %%
import os
print(os.getcwd())  # Get current working directory
# Out:
# /Users/itamarshamir/Documents/code/Vision/unet/src

# %%
import sys
sys.path.append("/Users/itamarshamir/Documents/code/Vision/")  # Adjust to your root path
